# %% [markdown]
# <a href="https://colab.research.google.com/github/ravishena14/ravishena14/blob/main/Stable_Diffusion_WebUi_Altryne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Stable Diffusion WebUI 1.4! by [@altryne](https://twitter.com/altryne/) |  [![ko-fi](https://ko-fi.com/img/githubbutton_sm.svg)](https://ko-fi.com/N4N3DWMR1)
#
# This colab runs the latest webui version from the repo https://github.com/hlky/stable-diffusion-webui
#
# ---
#
# If this colab helped you, support me on ko-fi and don't forget to subscribe to my awesome list https://github.com/altryne/awesome-ai-art-image-synthesis

# %% [markdown]
# ## 1 -  Setup stage

# %% [markdown]
# ### 1.0

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-97b6a51f-8d61-7d11-0940-c55d2578926e)

# %% [markdown]
# ### 1.1 Download repo and install
#
# Clone git repo and setup miniconda

# %%
#@markdown ## Download the stable-diffusion webui repo
#@markdown And install colab related conda (uncheck stable version if you like new features)
# %cd /content
# !git clone https://github.com/hlky/stable-diffusion
# %cd /content/stable-diffusion
stable_version = True #@param {type:"boolean"}
if stable_version:
  # !git checkout colab-pin

import sys
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# !rm Miniconda3-latest-Linux-x86_64.sh
# Out:
# /content
# Cloning into 'stable-diffusion'...
# remote: Enumerating objects: 1162, done.
# remote: Total 1162 (delta 0), reused 0 (delta 0), pack-reused 1162 (from 1)
# Receiving objects: 100% (1162/1162), 42.81 MiB | 33.77 MiB/s, done.
# Resolving deltas: 100% (557/557), done.
# /content/stable-diffusion
# Branch 'colab-pin' set up to track remote branch 'colab-pin' from 'origin'.
# Switched to a new branch 'colab-pin'
# --2025-02-26 05:07:19--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 154615621 (147M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 147.45M   178MB/s    in 0.8s
#
# 2025-02-26 05:07:20 (178 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [154615621/154615621]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %% [markdown]
# ### 1.2 Environment setup
# Setup environment, Gfpgan and Real-ESRGAN. Takes about 5-6 minutes

# %%
#@markdown ### Set up conda environment - Takes a while
# !conda env update -n base -f /content/stable-diffusion/environment.yaml
# Out:
# Channels:
#  - pytorch
#  - defaults
# Platform: linux-64
# done
# failed
#
# LibMambaUnsatisfiableError: Encountered problems while solving:
#   - package conda-25.1.1-py312h06a4308_0 has constraint conda-anaconda-telemetry >=0.1.2 conflicting with conda-anaconda-telemetry-0.1.1-py39h06a4308_0
#
# Could not solve for environment specs
# The following packages are incompatible
# ├─ conda-anaconda-telemetry =* * is installable with the potential options
# │  ├─ conda-anaconda-telemetry 0.1.1 would require
# │  │  └─ conda >=24.11 *, which requires
# │  │     └─ conda-anaconda-telemetry >=0.1.2 *, which can be installed;
# │  ├─ conda-anaconda-telemetry 0.1.2 would require
# │  │  └─ python >=3.10,<3.11.0a0 *, which can be installed;
# │  ├─ conda-anaconda-telemetry 0.1.2 would require
# │  │  └─ python >=3.11,<3.12.0a0 *, which can be installed;
# │  ├─ conda-anaconda-telemetry 0.1.2 would require
# │  │  └─ python >=3.12,<3.13.0a0 *, which can be installed;
# │  └─ conda-anaconda-telemetry 0.1.2 would require
# │     └─ python >=3.9,<3.10.0a0 *, which can be installed;
# └─ python =3.8.5 * is not installable because it conflicts with any installable versions previously reported.

# %% [markdown]
# ### 1.3 Setup Upscalers - CFPGan and ESRGAN

# %%
#@markdown ### Build upscalers support
#@markdown **GFPGAN** Automatically correct distorted faces with a built-in GFPGAN option, fixes them in less than half a second
#@markdown **ESRGAN** Boosts the resolution of images with a built-in RealESRGAN option
#@markdown LDSR and GoBig enable amazing upscale options in the new Image Lab

add_CFP = True #@param {type:"boolean"}
add_ESR = True #@param {type:"boolean"}
add_LDSR = False #@param {type:"boolean"}
#@markdown ⚠️ LDSR is 1.9GB and make take time to download

if add_CFP:
  # %cd /content/stable-diffusion/src/gfpgan/
  # !pip install basicsr facexlib yapf lmdb opencv-python pyyaml tb-nightly --no-deps
  # !python setup.py develop
  # !pip install realesrgan
  # !wget https://github.com/TencentARC/GFPGAN/releases/download/v1.3.0/GFPGANv1.3.pth -P experiments/pretrained_models
if add_ESR:
  # %cd /content/stable-diffusion/src/realesrgan/
  # !wget https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth -P experiments/pretrained_models
  # !wget https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.2.4/RealESRGAN_x4plus_anime_6B.pth -P experiments/pretrained_models
if add_LDSR:
  # %cd /content/stable-diffusion/src
  # !git clone https://github.com/devilismyfriend/latent-diffusion
  # %cd latent-diffusion
  # %mkdir -p experiments/
  # %cd experiments/
  # %mkdir -p pretrained_models
  # %cd pretrained_models
  #project.yaml download
  # !wget -O project.yaml https://heibox.uni-heidelberg.de/f/31a76b13ea27482981b4/?dl=1
  #model.ckpt model download
  # !wget -O model.ckpt https://heibox.uni-heidelberg.de/f/578df07c8fc04ffbadf3/?dl=1

# %cd /content/stable-diffusion/
# !wget https://github.com/matomo-org/travis-scripts/blob/master/fonts/Arial.ttf?raw=true -O arial.ttf
# Out:
# [Errno 2] No such file or directory: '/content/stable-diffusion/src/gfpgan/'
# /content/stable-diffusion
# Collecting basicsr
#   Downloading basicsr-1.4.2.tar.gz (172 kB)
#   Preparing metadata (setup.py) ... done
# Collecting facexlib
#   Downloading facexlib-0.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting yapf
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
# Collecting lmdb
#   Downloading lmdb-1.6.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pyyaml
#   Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting tb-nightly
#   Downloading tb_nightly-2.20.0a20250225-py3-none-any.whl.metadata (1.8 kB)
# Downloading facexlib-0.3.0-py3-none-any.whl (59 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
# Downloading lmdb-1.6.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 50.9 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 33.0 MB/s eta 0:00:00
# Downloading tb_nightly-2.20.0a20250225-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 102.5 MB/s eta 0:00:00
# Building wheels for collected packages: basicsr
#   Building wheel for basicsr (setup.py) ... done
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214873 sha256=88e10eca691814a3e7e33497b43bc8a73321169fc941ff7ee27ea8c24b7caa8b
#   Stored in directory: /root/.cache/pip/wheels/9a/e3/e4/58f29bfabb622dd40b6d9839318ce5bf092062b81ca3aa19ea
# Successfully built basicsr
# Installing collected packages: lmdb, facexlib, basicsr, yapf, tb-nightly, pyyaml, opencv-python
# Successfully installed basicsr-1.4.2 facexlib-0.3.0 lmdb-1.6.2 opencv-python-4.11.0.86 pyyaml-6.0.2 tb-nightly-2.20.0a20250225 yapf-0.43.0
# running develop
# /usr/local/lib/python3.12/site-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.12/site-packages/setuptools/_distutils/cmd.py:79: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running egg_info
# creating latent_diffusion.egg-info
# writing latent_diffusion.egg-info/PKG-INFO
# writing dependency_links to latent_diffusion.egg-info/dependency_links.txt
# writing requirements to latent_diffusion.egg-info/requires.txt
# writing top-level names to latent_diffusion.egg-info/top_level.txt
# writing manifest file 'latent_diffusion.egg-info/SOURCES.txt'
# reading manifest file 'latent_diffusion.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'latent_diffusion.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.12/site-packages/latent-diffusion.egg-link (link to .)
# Adding latent-diffusion 0.0.1 to easy-install.pth file
#
# Installed /content/stable-diffusion
# Processing dependencies for latent-diffusion==0.0.1
# Searching for numpy
# Reading https://pypi.org/simple/numpy/
# Downloading https://files.pythonhosted.org/packages/39/04/78d2e7402fb479d893953fb78fa7045f7deb635ec095b6b4f0260223091a/numpy-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=3b787adbf04b0db1967798dba8da1af07e387908ed1553a0d6e74c084d1ceafe
# Best match: numpy 2.2.3
# Processing numpy-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing numpy-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding numpy 2.2.3 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing numpy-config script to /usr/local/bin
#
# Installed /usr/local/lib/python3.12/site-packages/numpy-2.2.3-py3.12-linux-x86_64.egg
# Searching for torch
# Reading https://pypi.org/simple/torch/
# Downloading https://files.pythonhosted.org/packages/e5/35/0c52d708144c2deb595cd22819a609f78fdd699b95ff6f0ebcd456e3c7c1/torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl#sha256=2bb8987f3bb1ef2675897034402373ddfc8f5ef0e156e2d8cfc47cacafdda4a9
# Best match: torch 2.6.0
# Processing torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl
# Installing torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding torch 2.6.0 to easy-install.pth file
# detected new path './numpy-2.2.3-py3.12-linux-x86_64.egg'
# Installing torchfrtrace script to /usr/local/bin
# Installing torchrun script to /usr/local/bin
#
# Installed /usr/local/lib/python3.12/site-packages/torch-2.6.0-py3.12-linux-x86_64.egg
# Searching for sympy==1.13.1
# Reading https://pypi.org/simple/sympy/
# Downloading https://files.pythonhosted.org/packages/b2/fe/81695a1aa331a842b582453b605175f419fe8540355886031328089d840a/sympy-1.13.1-py3-none-any.whl#sha256=db36cdc64bf61b9b24578b6f7bab1ecdd2452cf008f34faa33776680c26d66f8
# Best match: sympy 1.13.1
# Processing sympy-1.13.1-py3-none-any.whl
# Installing sympy-1.13.1-py3-none-any.whl to /usr/local/lib/python3.12/site-packages
# Adding sympy 1.13.1 to easy-install.pth file
# detected new path './torch-2.6.0-py3.12-linux-x86_64.egg'
# Installing isympy script to /usr/local/bin
#
# Installed /usr/local/lib/python3.12/site-packages/sympy-1.13.1-py3.12.egg
# Searching for triton==3.2.0
# Reading https://pypi.org/simple/triton/
# Downloading https://files.pythonhosted.org/packages/06/00/59500052cb1cf8cf5316be93598946bc451f14072c6ff256904428eaf03c/triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=8d9b215efc1c26fa7eefb9a157915c92d52e000d2bf83e5f69704047e63f125c
# Best match: triton 3.2.0
# Processing triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding triton 3.2.0 to easy-install.pth file
# detected new path './sympy-1.13.1-py3.12.egg'
# Installing proton script to /usr/local/bin
# Installing proton-viewer script to /usr/local/bin
#
# Installed /usr/local/lib/python3.12/site-packages/triton-3.2.0-py3.12-linux-x86_64.egg
# Searching for nvidia-nvjitlink-cu12==12.4.127
# Reading https://pypi.org/simple/nvidia-nvjitlink-cu12/
# Downloading https://files.pythonhosted.org/packages/ff/ff/847841bacfbefc97a00036e0fce5a0f086b640756dc38caea5e1bb002655/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl#sha256=06b3b9b25bf3f8af351d664978ca26a16d2c5127dbd53c0497e28d1fb9611d57
# Best match: nvidia-nvjitlink-cu12 12.4.127
# Processing nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-nvjitlink-cu12 12.4.127 to easy-install.pth file
# detected new path './triton-3.2.0-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_nvjitlink_cu12-12.4.127-py3.12-linux-x86_64.egg
# Searching for nvidia-nvtx-cu12==12.4.127
# Reading https://pypi.org/simple/nvidia-nvtx-cu12/
# Downloading https://files.pythonhosted.org/packages/87/20/199b8713428322a2f22b722c62b8cc278cc53dffa9705d744484b5035ee9/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl#sha256=781e950d9b9f60d8241ccea575b32f5105a5baf4c2351cab5256a24869f12a1a
# Best match: nvidia-nvtx-cu12 12.4.127
# Processing nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-nvtx-cu12 12.4.127 to easy-install.pth file
# detected new path './nvidia_nvjitlink_cu12-12.4.127-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_nvtx_cu12-12.4.127-py3.12-linux-x86_64.egg
# Searching for nvidia-nccl-cu12==2.21.5
# Reading https://pypi.org/simple/nvidia-nccl-cu12/
# Downloading https://files.pythonhosted.org/packages/df/99/12cd266d6233f47d00daf3a72739872bdc10267d0383508b0b9c84a18bb6/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl#sha256=8579076d30a8c24988834445f8d633c697d42397e92ffc3f63fa26766d25e0a0
# Best match: nvidia-nccl-cu12 2.21.5
# Processing nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-nccl-cu12 2.21.5 to easy-install.pth file
# detected new path './nvidia_nvtx_cu12-12.4.127-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_nccl_cu12-2.21.5-py3.12-linux-x86_64.egg
# Searching for nvidia-cusparselt-cu12==0.6.2
# Reading https://pypi.org/simple/nvidia-cusparselt-cu12/
# Downloading https://files.pythonhosted.org/packages/78/a8/bcbb63b53a4b1234feeafb65544ee55495e1bb37ec31b999b963cbccfd1d/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl#sha256=df2c24502fd76ebafe7457dbc4716b2fec071aabaed4fb7691a201cde03704d9
# Best match: nvidia-cusparselt-cu12 0.6.2
# Processing nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-cusparselt-cu12 0.6.2 to easy-install.pth file
# detected new path './nvidia_nccl_cu12-2.21.5-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_cusparselt_cu12-0.6.2-py3.12-linux-x86_64.egg
# Searching for nvidia-cusparse-cu12==12.3.1.170
# Reading https://pypi.org/simple/nvidia-cusparse-cu12/
# Downloading https://files.pythonhosted.org/packages/db/f7/97a9ea26ed4bbbfc2d470994b8b4f338ef663be97b8f677519ac195e113d/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl#sha256=ea4f11a2904e2a8dc4b1833cc1b5181cde564edd0d5cd33e3c168eff2d1863f1
# Best match: nvidia-cusparse-cu12 12.3.1.170
# Processing nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-cusparse-cu12 12.3.1.170 to easy-install.pth file
# detected new path './nvidia_cusparselt_cu12-0.6.2-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_cusparse_cu12-12.3.1.170-py3.12-linux-x86_64.egg
# Searching for nvidia-cusolver-cu12==11.6.1.9
# Reading https://pypi.org/simple/nvidia-cusolver-cu12/
# Downloading https://files.pythonhosted.org/packages/3a/e1/5b9089a4b2a4790dfdea8b3a006052cfecff58139d5a4e34cb1a51df8d6f/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl#sha256=19e33fa442bcfd085b3086c4ebf7e8debc07cfe01e11513cc6d332fd918ac260
# Best match: nvidia-cusolver-cu12 11.6.1.9
# Processing nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-cusolver-cu12 11.6.1.9 to easy-install.pth file
# detected new path './nvidia_cusparse_cu12-12.3.1.170-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_cusolver_cu12-11.6.1.9-py3.12-linux-x86_64.egg
# Searching for nvidia-curand-cu12==10.3.5.147
# Reading https://pypi.org/simple/nvidia-curand-cu12/
# Downloading https://files.pythonhosted.org/packages/8a/6d/44ad094874c6f1b9c654f8ed939590bdc408349f137f9b98a3a23ccec411/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl#sha256=a88f583d4e0bb643c49743469964103aa59f7f708d862c3ddb0fc07f851e3b8b
# Best match: nvidia-curand-cu12 10.3.5.147
# Processing nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-curand-cu12 10.3.5.147 to easy-install.pth file
# detected new path './nvidia_cusolver_cu12-11.6.1.9-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_curand_cu12-10.3.5.147-py3.12-linux-x86_64.egg
# Searching for nvidia-cufft-cu12==11.2.1.3
# Reading https://pypi.org/simple/nvidia-cufft-cu12/
# Downloading https://files.pythonhosted.org/packages/27/94/3266821f65b92b3138631e9c8e7fe1fb513804ac934485a8d05776e1dd43/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl#sha256=f083fc24912aa410be21fa16d157fed2055dab1cc4b6934a0e03cba69eb242b9
# Best match: nvidia-cufft-cu12 11.2.1.3
# Processing nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-cufft-cu12 11.2.1.3 to easy-install.pth file
# detected new path './nvidia_curand_cu12-10.3.5.147-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_cufft_cu12-11.2.1.3-py3.12-linux-x86_64.egg
# Searching for nvidia-cublas-cu12==12.4.5.8
# Reading https://pypi.org/simple/nvidia-cublas-cu12/
# Downloading https://files.pythonhosted.org/packages/ae/71/1c91302526c45ab494c23f61c7a84aa568b8c1f9d196efa5993957faf906/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl#sha256=2fc8da60df463fdefa81e323eef2e36489e1c94335b5358bcb38360adf75ac9b
# Best match: nvidia-cublas-cu12 12.4.5.8
# Processing nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-cublas-cu12 12.4.5.8 to easy-install.pth file
# detected new path './nvidia_cufft_cu12-11.2.1.3-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_cublas_cu12-12.4.5.8-py3.12-linux-x86_64.egg
# Searching for nvidia-cudnn-cu12==9.1.0.70
# Reading https://pypi.org/simple/nvidia-cudnn-cu12/
# Downloading https://files.pythonhosted.org/packages/9f/fd/713452cd72343f682b1c7b9321e23829f00b842ceaedcda96e742ea0b0b3/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl#sha256=165764f44ef8c61fcdfdfdbe769d687e06374059fbb388b6c89ecb0e28793a6f
# Best match: nvidia-cudnn-cu12 9.1.0.70
# Processing nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-cudnn-cu12 9.1.0.70 to easy-install.pth file
# detected new path './nvidia_cublas_cu12-12.4.5.8-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_cudnn_cu12-9.1.0.70-py3.12-linux-x86_64.egg
# Searching for nvidia-cuda-cupti-cu12==12.4.127
# Reading https://pypi.org/simple/nvidia-cuda-cupti-cu12/
# Downloading https://files.pythonhosted.org/packages/67/42/f4f60238e8194a3106d06a058d494b18e006c10bb2b915655bd9f6ea4cb1/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl#sha256=9dec60f5ac126f7bb551c055072b69d85392b13311fcc1bcda2202d172df30fb
# Best match: nvidia-cuda-cupti-cu12 12.4.127
# Processing nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-cuda-cupti-cu12 12.4.127 to easy-install.pth file
# detected new path './nvidia_cudnn_cu12-9.1.0.70-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_cuda_cupti_cu12-12.4.127-py3.12-linux-x86_64.egg
# Searching for nvidia-cuda-runtime-cu12==12.4.127
# Reading https://pypi.org/simple/nvidia-cuda-runtime-cu12/
# Downloading https://files.pythonhosted.org/packages/ea/27/1795d86fe88ef397885f2e580ac37628ed058a92ed2c39dc8eac3adf0619/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl#sha256=64403288fa2136ee8e467cdc9c9427e0434110899d07c779f25b5c068934faa5
# Best match: nvidia-cuda-runtime-cu12 12.4.127
# Processing nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-cuda-runtime-cu12 12.4.127 to easy-install.pth file
# detected new path './nvidia_cuda_cupti_cu12-12.4.127-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_cuda_runtime_cu12-12.4.127-py3.12-linux-x86_64.egg
# Searching for nvidia-cuda-nvrtc-cu12==12.4.127
# Reading https://pypi.org/simple/nvidia-cuda-nvrtc-cu12/
# Downloading https://files.pythonhosted.org/packages/2c/14/91ae57cd4db3f9ef7aa99f4019cfa8d54cb4caa7e00975df6467e9725a9f/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl#sha256=a178759ebb095827bd30ef56598ec182b85547f1508941a3d560eb7ea1fbf338
# Best match: nvidia-cuda-nvrtc-cu12 12.4.127
# Processing nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding nvidia-cuda-nvrtc-cu12 12.4.127 to easy-install.pth file
# detected new path './nvidia_cuda_runtime_cu12-12.4.127-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/nvidia_cuda_nvrtc_cu12-12.4.127-py3.12-linux-x86_64.egg
# Searching for fsspec
# Reading https://pypi.org/simple/fsspec/
# Downloading https://files.pythonhosted.org/packages/e2/94/758680531a00d06e471ef649e4ec2ed6bf185356a7f9fbfbb7368a40bd49/fsspec-2025.2.0-py3-none-any.whl#sha256=9de2ad9ce1f85e1931858535bc882543171d197001a0a5eb2ddc04f1781ab95b
# Best match: fsspec 2025.2.0
# Processing fsspec-2025.2.0-py3-none-any.whl
# Installing fsspec-2025.2.0-py3-none-any.whl to /usr/local/lib/python3.12/site-packages
# Adding fsspec 2025.2.0 to easy-install.pth file
# detected new path './nvidia_cuda_nvrtc_cu12-12.4.127-py3.12-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/fsspec-2025.2.0-py3.12.egg
# Searching for jinja2
# Reading https://pypi.org/simple/jinja2/
# Downloading https://files.pythonhosted.org/packages/bd/0f/2ba5fbcd631e3e88689309dbe978c5769e883e4b84ebfe7da30b43275c5a/jinja2-3.1.5-py3-none-any.whl#sha256=aba0f4dc9ed8013c424088f68a5c226f7d6097ed89b246d7749c2ec4175c6adb
# Best match: jinja2 3.1.5
# Processing jinja2-3.1.5-py3-none-any.whl
# Installing jinja2-3.1.5-py3-none-any.whl to /usr/local/lib/python3.12/site-packages
# Adding jinja2 3.1.5 to easy-install.pth file
# detected new path './fsspec-2025.2.0-py3.12.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/jinja2-3.1.5-py3.12.egg
# Searching for networkx
# Reading https://pypi.org/simple/networkx/
# Downloading https://files.pythonhosted.org/packages/b9/54/dd730b32ea14ea797530a4479b2ed46a6fb250f682a9cfb997e968bf0261/networkx-3.4.2-py3-none-any.whl#sha256=df5d4365b724cf81b8c6a7312509d0c22386097011ad1abe274afd5e9d3bbc5f
# Best match: networkx 3.4.2
# Processing networkx-3.4.2-py3-none-any.whl
# Installing networkx-3.4.2-py3-none-any.whl to /usr/local/lib/python3.12/site-packages
# Adding networkx 3.4.2 to easy-install.pth file
# detected new path './jinja2-3.1.5-py3.12.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/networkx-3.4.2-py3.12.egg
# Searching for filelock
# Reading https://pypi.org/simple/filelock/
# Downloading https://files.pythonhosted.org/packages/89/ec/00d68c4ddfedfe64159999e5f8a98fb8442729a63e2077eb9dcd89623d27/filelock-3.17.0-py3-none-any.whl#sha256=533dc2f7ba78dc2f0f531fc6c4940addf7b70a481e269a5a3b93be94ffbe8338
# Best match: filelock 3.17.0
# Processing filelock-3.17.0-py3-none-any.whl
# Installing filelock-3.17.0-py3-none-any.whl to /usr/local/lib/python3.12/site-packages
# Adding filelock 3.17.0 to easy-install.pth file
# detected new path './networkx-3.4.2-py3.12.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/filelock-3.17.0-py3.12.egg
# Searching for mpmath<1.4,>=1.1.0
# Reading https://pypi.org/simple/mpmath/
# Downloading https://files.pythonhosted.org/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl#sha256=a0b2b9fe80bbcd81a6647ff13108738cfb482d481d826cc0e02f5b35e5c88d2c
# Best match: mpmath 1.3.0
# Processing mpmath-1.3.0-py3-none-any.whl
# Installing mpmath-1.3.0-py3-none-any.whl to /usr/local/lib/python3.12/site-packages
# Adding mpmath 1.3.0 to easy-install.pth file
# detected new path './filelock-3.17.0-py3.12.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/mpmath-1.3.0-py3.12.egg
# Searching for MarkupSafe>=2.0
# Reading https://pypi.org/simple/MarkupSafe/
# Downloading https://files.pythonhosted.org/packages/f3/f0/89e7aadfb3749d0f52234a0c8c7867877876e0a20b60e2188e9850794c17/MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=e17c96c14e19278594aa4841ec148115f9c7615a47382ecb6b82bd8fea3ab0c8
# Best match: MarkupSafe 3.0.2
# Processing MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.12/site-packages
# Adding MarkupSafe 3.0.2 to easy-install.pth file
# detected new path './mpmath-1.3.0-py3.12.egg'
#
# Installed /usr/local/lib/python3.12/site-packages/MarkupSafe-3.0.2-py3.12-linux-x86_64.egg
# Searching for tqdm==4.67.1
# Best match: tqdm 4.67.1
# Adding tqdm 4.67.1 to easy-install.pth file
# detected new path './MarkupSafe-3.0.2-py3.12-linux-x86_64.egg'
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.12/site-packages
# Searching for setuptools==75.8.0
# Best match: setuptools 75.8.0
# Adding setuptools 75.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.12/site-packages
# Searching for typing-extensions==4.12.2
# Best match: typing-extensions 4.12.2
# Adding typing-extensions 4.12.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.12/site-packages/setuptools/_vendor
# Finished processing dependencies for latent-diffusion==0.0.1
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/mpmath-1.3.0-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_nvjitlink_cu12-12.4.127-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/fsspec-2025.2.0-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_nccl_cu12-2.21.5-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_curand_cu12-10.3.5.147-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/sympy-1.13.1-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_nvtx_cu12-12.4.127-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_cusparse_cu12-12.3.1.170-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_cuda_runtime_cu12-12.4.127-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_cuda_cupti_cu12-12.4.127-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_cufft_cu12-11.2.1.3-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/torch-2.6.0-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/jinja2-3.1.5-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/MarkupSafe-3.0.2-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/networkx-3.4.2-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_cusparselt_cu12-0.6.2-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/numpy-2.2.3-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/triton-3.2.0-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_cublas_cu12-12.4.5.8-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/filelock-3.17.0-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_cusolver_cu12-11.6.1.9-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_cuda_nvrtc_cu12-12.4.127-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/site-packages/nvidia_cudnn_cu12-9.1.0.70-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting realesrgan
#   Downloading realesrgan-0.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: basicsr>=1.4.2 in /usr/local/lib/python3.12/site-packages (from realesrgan) (1.4.2)
# Requirement already satisfied: facexlib>=0.2.5 in /usr/local/lib/python3.12/site-packages (from realesrgan) (0.3.0)
# Collecting gfpgan>=1.3.5 (from realesrgan)
#   Downloading gfpgan-1.3.8-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/site-packages/numpy-2.2.3-py3.12-linux-x86_64.egg (from realesrgan) (2.2.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/site-packages (from realesrgan) (4.11.0.86)
# Collecting Pillow (from realesrgan)
#   Downloading pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.12/site-packages/torch-2.6.0-py3.12-linux-x86_64.egg (from realesrgan) (2.6.0)
# Collecting torchvision (from realesrgan)
#   Downloading torchvision-0.21.0-cp312-cp312-manylinux1_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/site-packages (from realesrgan) (4.67.1)
# Collecting addict (from basicsr>=1.4.2->realesrgan)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting future (from basicsr>=1.4.2->realesrgan)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.12/site-packages (from basicsr>=1.4.2->realesrgan) (1.6.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/site-packages (from basicsr>=1.4.2->realesrgan) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/site-packages (from basicsr>=1.4.2->realesrgan) (2.32.3)
# Collecting scikit-image (from basicsr>=1.4.2->realesrgan)
#   Downloading scikit_image-0.25.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting scipy (from basicsr>=1.4.2->realesrgan)
#   Downloading scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: tb-nightly in /usr/local/lib/python3.12/site-packages (from basicsr>=1.4.2->realesrgan) (2.20.0a20250225)
# Requirement already satisfied: yapf in /usr/local/lib/python3.12/site-packages (from basicsr>=1.4.2->realesrgan) (0.43.0)
# Collecting filterpy (from facexlib>=0.2.5->realesrgan)
#   Downloading filterpy-1.4.5.zip (177 kB)
#   Preparing metadata (setup.py) ... done
# Collecting numba (from facexlib>=0.2.5->realesrgan)
#   Downloading numba-0.61.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/site-packages/filelock-3.17.0-py3.12.egg (from torch>=1.7->realesrgan) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/site-packages (from torch>=1.7->realesrgan) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/site-packages/networkx-3.4.2-py3.12.egg (from torch>=1.7->realesrgan) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/site-packages/jinja2-3.1.5-py3.12.egg (from torch>=1.7->realesrgan) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/site-packages/fsspec-2025.2.0-py3.12.egg (from torch>=1.7->realesrgan) (2025.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/site-packages/nvidia_cuda_nvrtc_cu12-12.4.127-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/site-packages/nvidia_cuda_runtime_cu12-12.4.127-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/site-packages/nvidia_cuda_cupti_cu12-12.4.127-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/site-packages/nvidia_cudnn_cu12-9.1.0.70-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/site-packages/nvidia_cublas_cu12-12.4.5.8-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/site-packages/nvidia_cufft_cu12-11.2.1.3-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/site-packages/nvidia_curand_cu12-10.3.5.147-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/site-packages/nvidia_cusolver_cu12-11.6.1.9-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/site-packages/nvidia_cusparse_cu12-12.3.1.170-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.12/site-packages/nvidia_cusparselt_cu12-0.6.2-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/site-packages/nvidia_nccl_cu12-2.21.5-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/site-packages/nvidia_nvtx_cu12-12.4.127-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/site-packages/nvidia_nvjitlink_cu12-12.4.127-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.12/site-packages/triton-3.2.0-py3.12-linux-x86_64.egg (from torch>=1.7->realesrgan) (3.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/site-packages (from torch>=1.7->realesrgan) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/site-packages/sympy-1.13.1-py3.12.egg (from torch>=1.7->realesrgan) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/site-packages/mpmath-1.3.0-py3.12.egg (from sympy==1.13.1->torch>=1.7->realesrgan) (1.3.0)
# Collecting matplotlib (from filterpy->facexlib>=0.2.5->realesrgan)
#   Downloading matplotlib-3.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/site-packages/MarkupSafe-3.0.2-py3.12-linux-x86_64.egg (from jinja2->torch>=1.7->realesrgan) (3.0.2)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba->facexlib>=0.2.5->realesrgan)
#   Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting numpy (from realesrgan)
#   Downloading numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/site-packages (from requests->basicsr>=1.4.2->realesrgan) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/site-packages (from requests->basicsr>=1.4.2->realesrgan) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/site-packages (from requests->basicsr>=1.4.2->realesrgan) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/site-packages (from requests->basicsr>=1.4.2->realesrgan) (2025.1.31)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->basicsr>=1.4.2->realesrgan)
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->basicsr>=1.4.2->realesrgan)
#   Downloading tifffile-2025.2.18-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/site-packages (from scikit-image->basicsr>=1.4.2->realesrgan) (24.2)
# Collecting lazy-loader>=0.4 (from scikit-image->basicsr>=1.4.2->realesrgan)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting absl-py>=0.4 (from tb-nightly->basicsr>=1.4.2->realesrgan)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tb-nightly->basicsr>=1.4.2->realesrgan)
#   Downloading grpcio-1.70.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting markdown>=2.6.8 (from tb-nightly->basicsr>=1.4.2->realesrgan)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tb-nightly->basicsr>=1.4.2->realesrgan)
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting six>1.9 (from tb-nightly->basicsr>=1.4.2->realesrgan)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tb-nightly->basicsr>=1.4.2->realesrgan)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tb-nightly->basicsr>=1.4.2->realesrgan)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/site-packages (from yapf->basicsr>=1.4.2->realesrgan) (3.10.0)
# Collecting contourpy>=1.0.1 (from matplotlib->filterpy->facexlib>=0.2.5->realesrgan)
#   Downloading contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib->filterpy->facexlib>=0.2.5->realesrgan)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->filterpy->facexlib>=0.2.5->realesrgan)
#   Downloading fonttools-4.56.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (101 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->filterpy->facexlib>=0.2.5->realesrgan)
#   Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->filterpy->facexlib>=0.2.5->realesrgan)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib->filterpy->facexlib>=0.2.5->realesrgan)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Downloading realesrgan-0.3.0-py3-none-any.whl (26 kB)
# Downloading gfpgan-1.3.8-py3-none-any.whl (52 kB)
# Downloading pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 77.9 MB/s eta 0:00:00
# Downloading torchvision-0.21.0-cp312-cp312-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 112.2 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading numba-0.61.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 65.4 MB/s eta 0:00:00
# Downloading numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 98.3 MB/s eta 0:00:00
# Downloading scikit_image-0.25.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 74.7 MB/s eta 0:00:00
# Downloading scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 44.6 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading grpcio-1.70.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 98.9 MB/s eta 0:00:00
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 47.9 MB/s eta 0:00:00
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 74.7 MB/s eta 0:00:00
# Downloading tifffile-2025.2.18-py3-none-any.whl (226 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading matplotlib-3.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 115.9 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 102.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 44.0 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110513 sha256=c539a88d58908290e62ad9da8371daf088e63f8b0c3d7a880c982969d1c83143
#   Stored in directory: /root/.cache/pip/wheels/77/bf/4c/b0c3f4798a0166668752312a67118b27a3cd341e13ac0ae6ee
# Successfully built filterpy
# Installing collected packages: addict, werkzeug, tensorboard-data-server, six, pyparsing, protobuf, Pillow, numpy, markdown, llvmlite, lazy-loader, kiwisolver, grpcio, future, fonttools, cycler, absl-py, tifffile, scipy, python-dateutil, numba, imageio, contourpy, scikit-image, matplotlib, torchvision, filterpy, gfpgan, realesrgan
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.3
#     Uninstalling numpy-2.2.3:
#       Successfully uninstalled numpy-2.2.3

# %% [markdown]
# ### 1.4 Connect to Google Drive

# %%
#@markdown # Load the stable-diffusion model

#@markdown **Model Path Variables**
# ask for the link
print("Local Path Variables:\n")

models_path = "/content/models" #@param {type:"string"}
output_path = "/content/output" #@param {type:"string"}

#@markdown **Download the model if it isn't already in the 'models_path' folder (Optional)**

#@markdown To download the model, you need to have accepted the terms [HERE](https://huggingface.co/CompVis/stable-diffusion-v1-4)
#@markdown and have copied a token from [HERE](https://huggingface.co/settings/tokens)
download_if_missing = False #@param {type:"boolean"}
token = "" #@param {type:"string"}

#@markdown **Google Drive Path Variables (Optional)**
mount_google_drive = True #@param {type:"boolean"}
force_remount = False

# %cd /content/
import os
mount_success = True
if mount_google_drive:
    from google.colab import drive
    try:
        drive_path = "/content/drive"
        drive.mount(drive_path,force_remount=force_remount)
        models_path_gdrive = "/content/drive/MyDrive/AI/models" #@param {type:"string"}
        output_path_gdrive = "/content/drive/MyDrive/AI/StableDiffusion" #@param {type:"string"}
        models_path = models_path_gdrive
        output_path = output_path_gdrive
    except:
        print("...error mounting drive or with drive path variables")
        print("...reverting to default path variables")
        mount_success = False

os.makedirs(models_path, exist_ok=True)
os.makedirs(output_path, exist_ok=True)

if download_if_missing:
    if not mount_success:
        print("Downloading model to " + models_path + " due to gdrive mount error")
    if token == "":
        print("No token provided. Assuming model is already in " + models_path)
    elif not os.path.exists(models_path + '/sd-v1-4.ckpt'):
        # !git lfs install --system --skip-repo
        # !mkdir sd-model
        # %cd /content/sd-model/
        # !git init
        # !git remote add -f origin "https://USER:{token}@huggingface.co/CompVis/stable-diffusion-v-1-4-original"
        # !git config core.sparsecheckout true
        # !echo "sd-v1-4.ckpt" > .git/info/sparse-checkout
        # !git pull origin main
        # !mv '/content/sd-model/sd-v1-4.ckpt' '{models_path}/'
    else:
        print("Model already downloaded, moving to next step")

print(f"models_path: {models_path}")
print(f"output_path: {output_path}")

# %% [markdown]
# ## 2 - Run the Stable Diffusion webui

# %% [markdown]
# ### 2.1 Optional - Set webUI settings and configs before running

# %%
#@markdown # Launch preferences - Advanced
share_password="" #@param {type:"string"}
#@markdown * Add a password to your webui
defaults="configs/webui/webui.yaml" #@param {type:"string"}
#@markdown * path to configuration file providing UI defaults, uses same format as cli parameter)
#@markdown Edit this file if you want to change the default settings UI launches with

#@markdown ---
save_metadata = False #@param {type:"boolean"}
#@markdown * Whether to embed the generation parameters in the sample images
skip_grid = False #@param {type:"boolean"}
#@markdown * Do not save a grid, only individual samples. Helpful when evaluating lots of samples
skip_save = False #@param {type:"boolean"}
#@markdown * Do not save individual samples as files. For speed measurements
optimized = False #@param {type:"boolean"}
#@markdown * Load the model onto the device piecemeal instead of all at once to reduce VRAM usage at the cost of performance
optimized_turbo = True #@param {type:"boolean"}
#@markdown * Alternative optimization mode that does not save as much VRAM but runs siginificantly faster
no_verify_input = False #@param {type:"boolean"}
#@markdown * Do not verify input to check if it's too long
no_half = False #@param {type:"boolean"}
#@markdown * Do not switch the model to 16-bit floats
no_progressbar_hiding = True #@param {type:"boolean"}
#@markdown * Do not hide progressbar in gradio UI
extra_models_cpu = False #@param {type:"boolean"}
#@markdown * Run extra models (GFGPAN/ESRGAN) on cpu
esrgan_cpu = True #@param {type:"boolean"}
#@markdown * run ESRGAN on cpu
gfpgan_cpu = False #@param {type:"boolean"}
#@markdown * run GFPGAN on cpu


run_string_with_variables = {
 '--save-metadata': f'{save_metadata}',
 '--skip-grid': f'{skip_grid}',
 '--skip-save': f'{skip_save}',
 '--optimized': f'{optimized}',
 '--optimized-turbo': f'{optimized_turbo}',
 '--no-verify-input': f'{no_verify_input}',
 '--no-half': f'{no_half}',
 '--no-progressbar-hiding': f'{no_progressbar_hiding}',
 '--extra-models-cpu': f'{extra_models_cpu}',
 '--esrgan-cpu': f'{esrgan_cpu}',
 '--gfpgan-cpu': f'{gfpgan_cpu}'}

only_true_vars = {k for (k,v) in run_string_with_variables.items() if v == 'True'}
vars = " ".join(only_true_vars)

# %% [markdown]
# ## 3 - Launch WebUI for stable diffusion

# %%
#@markdown ** keep in mind that this script is set to run for ever, google will disconnect you after 90 minutes on free tiers

#@markdown # Important - click the public URL to launch WebUI in another tab
#@markdown ![](https://user-images.githubusercontent.com/463317/187105407-dd9b0f4e-c8da-49d3-8c78-1767f5c9aa83.jpg)

#fix adding share_password to the launch params, and also changin {vars} to $vars as it was causing webui.py to fail.

# %cd /content/stable-diffusion

if share_password == "":
  # !python scripts/webui.py \
  --ckpt '{models_path}/sd-v1-4.ckpt' \
  --outdir '{output_path}' \
  --share $vars
else:
  # !python scripts/webui.py \
  --ckpt '{models_path}/sd-v1-4.ckpt' \
  --outdir '{output_path}' \
  --share-password '{share_password}' \
  --share $vars
